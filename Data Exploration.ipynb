# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
from IPython.display import Image

# %%
file_path = 'C:\\hudsondata\\Machine Learning\\Kaggle\\Leaves'

# %%
train = pd.read_csv(os.path.join(file_path,'train.csv'))
test = pd.read_csv(os.path.join(file_path,'test.csv'))
benchmark = pd.read_csv(os.path.join(file_path,'sample_submission.csv'))

# %% [markdown]
# # Top 5 Rows and Dataset Shapes

# %%
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8    ...      texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0    ...       0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0    ...       0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0    ...       0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0    ...       0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0    ...       0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# ...

# %%
test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9    ...      texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859    ...       0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203    ...       0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719    ...       0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906    ...       0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859    ...       0.000000   0.042969   0.016602   0.010742
#
# ...

# %%
print 'The train shape is', train.shape, 'the test shape is', test.shape
# Out:
# The train shape is (990, 194) the test shape is (594, 193)

# %%
train.dtypes.head()
# Out:
# id           int64
# species     object
# margin1    float64
# margin2    float64
# margin3    float64
# dtype: object

# %% [markdown]
# # Feature 1 - Margin

# %%
margin = train.iloc[:,2:66]

# %%
Image(filename='C://hudsondata//Machine Learning//Kaggle//Leaves//images//11.jpg', width=100)

# %%
plt.bar(range(64),margin.iloc[7])
plt.xlabel('Margin 1-64')
plt.ylabel('Margin')
plt.title('Specie: Quercus_Rubra', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
Image(filename='C://hudsondata//Machine Learning//Kaggle//Leaves//images//37.jpg', width=100)

# %%
plt.bar(range(64),margin.iloc[24])
plt.xlabel('Margin 1-64')
plt.ylabel('Margin')
plt.title('Specie: Arundinaria_Simonii', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
Image(filename='C://hudsondata//Machine Learning//Kaggle//Leaves//images//45.jpg', width=100)

# %%
plt.bar(range(64),margin.iloc[29])
plt.xlabel('Margin 1-64')
plt.ylabel('Margin')
plt.title('Specie: Fagus_Sylvatica', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
print 'The maximum value for the margin feature is ', margin.max().max(), 'the minimum value for the margin feature is ', margin.min().min()
# Out:
# The maximum value for the margin feature is  0.38867 the minimum value for the margin feature is  0.0

# %% [markdown]
# # Feature 2 - Shape

# %%
shape = train.iloc[:,66:130]

# %%
plt.bar(range(64),shape.iloc[7])
plt.xlabel('Shape 1-64')
plt.ylabel('Shape')
plt.title('Specie: Quercus_Rubra ID 7', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
plt.bar(range(64),shape.iloc[24])
plt.xlabel('Shape 1-64')
plt.ylabel('Shape')
plt.title('Specie: Arundinaria_Simonii', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
plt.bar(range(64),shape.iloc[29])
plt.xlabel('Shape 1-64')
plt.ylabel('Shape')
plt.title('Specie: Fagus_Sylvatica', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
train[train['species']=='Quercus_Rubra']
# Out:
#        id        species   margin1   margin2   margin3   margin4   margin5  \
# 7      11  Quercus_Rubra  0.000000  0.000000  0.037109  0.050781  0.003906
# 209   356  Quercus_Rubra  0.001953  0.000000  0.031250  0.062500  0.015625
# 228   383  Quercus_Rubra  0.000000  0.000000  0.060547  0.056641  0.003906
# 232   389  Quercus_Rubra  0.001953  0.000000  0.039062  0.046875  0.013672
# 252   420  Quercus_Rubra  0.003906  0.001953  0.058594  0.048828  0.005859
# 359   593  Quercus_Rubra  0.000000  0.003906  0.050781  0.052734  0.005859
# 617   978  Quercus_Rubra  0.000000  0.000000  0.041016  0.031250  0.011719
# 703  1128  Quercus_Rubra  0.001953  0.000000  0.044922  0.035156  0.001953
# 891  1432  Quercus_Rubra  0.000000  0.000000  0.025391  0.148440  0.005859
# 988  1582  Quercus_Rubra  0.000000  0.000000  0.046875  0.056641  0.009766
#
#       margin6   margin7  margin8    ...      texture55  texture56  texture57  \
# ...

# %%
plt.bar(range(64),shape.iloc[209])
plt.xlabel('Shape 1-64')
plt.ylabel('Shape')
plt.title('Specie: Quercus_Rubra ID 209', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
print 'The maximum value for the shape feature is ', shape.max().max(), 'the minimum value for the shape feature is ', shape.min().min()
# Out:
# The maximum value for the shape feature is  0.0030067 the minimum value for the shape feature is  2.1672e-05

# %% [markdown]
# # Feature 3 - Texture

# %%
texture = train.iloc[:,130:]

# %%
plt.bar(range(64),texture.mean())
plt.xlabel('Texture 1-64')
plt.ylabel('Texture')
plt.title('Mean for Each of the Texture Attribute', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
plt.bar(range(64),990-(texture.astype(bool).sum(axis=0)))
plt.xlabel('Texture 1-64')
plt.ylabel('Count of Zeros')
plt.title('Number of Zeros per Texture Attribute', fontsize=20)
plt.xlim(0,64)
# Out:
# (0, 64)

# %%
print ' The average number of zeros in the texture attribute for every leaf sample is:', (64-(texture.astype(bool).sum(axis=1))).mean()
# Out:
#  The average number of zeros in the texture attribute for every leaf sample is: 23.6717171717

# %%
print 'The maximum value for the texture feature is ', texture.max().max(), 'the minimum value for the texture feature is ', texture.min().min()
# Out:
# The maximum value for the texture feature is  0.85352 the minimum value for the texture feature is  0.0

# %% [markdown]
# # Benchmark

# %%
benchmark.head()
# Out:
#    id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0   4         0.010101         0.010101   0.010101     0.010101
# 1   7         0.010101         0.010101   0.010101     0.010101
# 2   9         0.010101         0.010101   0.010101     0.010101
# 3  12         0.010101         0.010101   0.010101     0.010101
# 4  13         0.010101         0.010101   0.010101     0.010101
#
#    Acer_Palmatum  Acer_Pictum  Acer_Platanoids  Acer_Rubrum  Acer_Rufinerve  \
# 0       0.010101     0.010101         0.010101     0.010101        0.010101
# 1       0.010101     0.010101         0.010101     0.010101        0.010101
# 2       0.010101     0.010101         0.010101     0.010101        0.010101
# 3       0.010101     0.010101         0.010101     0.010101        0.010101
# 4       0.010101     0.010101         0.010101     0.010101        0.010101
#
#         ...         Salix_Fragilis  Salix_Intergra  Sorbus_Aria  \
# ...
